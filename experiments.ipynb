# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammedOwaiskh/prompt-reasoning-at-scale/blob/master/experiments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers datasets accelerate sentencepiece protobuf -q

# %%
# !git clone https://github.com/mohammedOwaiskh/prompt-reasoning-at-scale.git
# %cd prompt-reasoning-at-scale
# Out:
# Cloning into 'prompt-reasoning-at-scale'...
# remote: Enumerating objects: 174, done.
# remote: Counting objects: 100% (174/174), done.
# remote: Compressing objects: 100% (133/133), done.
# Receiving objects: 100% (174/174), 252.42 KiB | 1.37 MiB/s, done.
# remote: Total 174 (delta 91), reused 105 (delta 37), pack-reused 0 (from 0)
# Resolving deltas: 100% (91/91), done.
# /content/prompt-reasoning-at-scale

# %%
# !git pull origin
# Out:
# Already up to date.

# %%
import os

os.makedirs("results", exist_ok=True)
os.makedirs("data", exist_ok=True)

# %%
from google.colab import userdata
from huggingface_hub import login

login(userdata.get("HF_TOKEN"))

# %%
# !python data/sample_data.py
# Out:
# Loading GSM8K Dataset...
# README.md: 7.93kB [00:00, 8.31MB/s]
# main/train-00000-of-00001.parquet: 100% 2.31M/2.31M [00:00<00:00, 2.81MB/s]
# main/test-00000-of-00001.parquet: 100% 419k/419k [00:00<00:00, 2.04MB/s]
# Generating train split: 100% 7473/7473 [00:00<00:00, 80726.17 examples/s]
# Generating test split: 100% 1319/1319 [00:00<00:00, 112621.11 examples/s]
# Saved: gsm8k.json
# Loading CommonsenseQA...
# README.md: 7.39kB [00:00, 19.5MB/s]
# data/train-00000-of-00001.parquet: 100% 1.25M/1.25M [00:00<00:00, 3.09MB/s]
# data/validation-00000-of-00001.parquet: 100% 160k/160k [00:00<00:00, 396kB/s]
# data/test-00000-of-00001.parquet: 100% 151k/151k [00:00<00:00, 710kB/s]
# Generating train split: 100% 9741/9741 [00:00<00:00, 196477.52 examples/s]
# Generating validation split: 100% 1221/1221 [00:00<00:00, 99435.86 examples/s]
# Generating test split: 100% 1140/1140 [00:00<00:00, 107752.26 examples/s]
# Saved: commonsenseqa.json

# %%
# !python experiments/run_standard.py
# Out:
# Loading Model: google/gemma-2b-it
# Using Device: cuda
# config.json: 100% 627/627 [00:00<00:00, 2.77MB/s]
# tokenizer_config.json: 34.2kB [00:00, 59.8MB/s]
# tokenizer.json: 100% 17.5M/17.5M [00:01<00:00, 17.2MB/s]
# special_tokens_map.json: 100% 636/636 [00:00<00:00, 3.31MB/s]
# model.safetensors.index.json: 13.5kB [00:00, 4.59MB/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 100% 5.01G/5.01G [00:54<00:00, 85.2MB/s]
# Fetching 2 files: 100% 2/2 [00:54<00:00, 27.27s/it]
# Download complete: 100% 5.01G/5.01G [00:54<00:00, 91.6MB/s]
# Loading weights: 100% 164/164 [00:14<00:00, 11.39it/s, Materializing param=model.norm.weight]
# generation_config.json: 100% 137/137 [00:00<00:00, 544kB/s]
#
# Running Zero-shot Standard Prompting | gemma-2b | gsm8k
# ------------------------------------------------------------
# Evaluating: 100% 100/100 [04:09<00:00,  2.49s/it]
#
# Accuracy: 8.00% (8/100)
# Results saved to: results/gsm8k_gemma-2b_standard.csv
# Loading Model: google/gemma-2b-it
# Using Device: cuda
# Loading weights: 100% 164/164 [00:12<00:00, 13.32it/s, Materializing param=model.norm.weight]
#
# Running Zero-shot Standard Prompting | gemma-2b | csqa
# ------------------------------------------------------------
# Evaluating: 100% 100/100 [01:52<00:00,  1.13s/it]
#
# Accuracy: 47.00% (47/100)
# Results saved to: results/csqa_gemma-2b_standard.csv

# %%
# !python experiments/run_fewshot.py
# Out:
# Loading Model: google/gemma-2b-it
# Using Device: cuda
# Loading weights: 100% 164/164 [00:05<00:00, 29.47it/s, Materializing param=model.norm.weight]
#
# Running Few-shot Standard Prompting (3-shot) | gemma-2b | gsm8k
# ------------------------------------------------------------
# Evaluating: 100% 100/100 [00:55<00:00,  1.79it/s]
#
# Accuracy: 6.00% (6/100)
# Results saved to: results/gsm8k_gemma-2b_fewshot.csv
# Loading Model: google/gemma-2b-it
# Using Device: cuda
# Loading weights: 100% 164/164 [00:05<00:00, 27.77it/s, Materializing param=model.norm.weight]
#
# Running Few-shot Standard Prompting (3-shot) | gemma-2b | csqa
# ------------------------------------------------------------
# Evaluating: 100% 100/100 [00:19<00:00,  5.07it/s]
#
# Accuracy: 43.00% (43/100)
# Results saved to: results/csqa_gemma-2b_fewshot.csv

# %%
# !python experiments/run_cot.py
# Out:
# Loading Model: google/gemma-2b-it
# Using Device: cuda
# Loading weights: 100% 164/164 [00:06<00:00, 25.92it/s, Materializing param=model.norm.weight]
#
# Running Zero-shot CoT Prompting | gemma-2b | gsm8k
# ------------------------------------------------------------
# Evaluating: 100% 100/100 [07:11<00:00,  4.31s/it]
#
# Accuracy: 12.00% (12/100)
# Results saved to: results/gsm8k_gemma-2b_cot.csv
# Loading Model: google/gemma-2b-it
# Using Device: cuda
# Loading weights: 100% 164/164 [00:06<00:00, 24.10it/s, Materializing param=model.norm.weight]
#
# Running Zero-shot CoT Prompting | gemma-2b | csqa
# ------------------------------------------------------------
# Evaluating: 100% 100/100 [04:59<00:00,  3.00s/it]
#
# Accuracy: 34.00% (34/100)
# Results saved to: results/csqa_gemma-2b_cot.csv

# %%
# !python experiments/run_self_consistency.py
# Out:
# Loading Model: google/gemma-2b-it
# Using Device: cuda
# Loading weights: 100% 164/164 [00:04<00:00, 34.38it/s, Materializing param=model.norm.weight]
#
# Running Self-Consistency CoT | gemma-2b | gsm8k
# Sampling 5x per question at temperature=0.7
# ------------------------------------------------------------
# Evaluating: 100% 100/100 [10:46<00:00,  6.46s/it]
#
# Accuracy:         19.00%
# Avg Consistency:  45.60%
# Results saved to: results/gsm8k_gemma-2b_self_consistency.csv
# Loading Model: google/gemma-2b-it
# Using Device: cuda
# Loading weights: 100% 164/164 [00:05<00:00, 28.86it/s, Materializing param=model.norm.weight]
#
# Running Self-Consistency CoT | gemma-2b | csqa
# Sampling 5x per question at temperature=0.7
# ------------------------------------------------------------
# Evaluating: 100% 100/100 [08:55<00:00,  5.35s/it]
#
# Accuracy:         29.00%
# Avg Consistency:  70.60%
# Results saved to: results/csqa_gemma-2b_self_consistency.csv

# %%
# !python analysis/evaluate.py
# Out:
# Loading results...
#
# ======================================================================
# SUMMARY TABLE
# ======================================================================
#             Strategy    Model  GSM8K Accuracy (%)  CSQA Accuracy (%)  GSM8K Consistency (%)  CSQA Consistency (%)
#   Zero-shot Standard gemma-2b                 8.0               47.0                    NaN                   NaN
#    Few-shot Standard gemma-2b                 6.0               43.0                    NaN                   NaN
#        Zero-shot CoT gemma-2b                12.0               34.0                    NaN                   NaN
# Self-Consistency CoT gemma-2b                19.0               29.0                   45.6                  70.6
#
# Saved: results/summary_table.csv
#
# Generating plots...
# Saved plot: results/plot_gsm8k_accuracy.png
# Saved plot: results/plot_csqa_accuracy.png
# Saved plot: results/plot_consistency_rates.png
#
# Done. All outputs saved to results/

# %% [markdown]
# ## Push on Git

# %%
commit_msg = str(input("Enter your commit message: "))

REPO = "prompt-reasoning-at-scale"
GITHUB_USERNAME = userdata.get("GITHUB_USERNAME")
GITHUB_TOKEN = userdata.get("GITHUB_TOKEN")

USER_EMAIL = userdata.get("USER_EMAIL")
USER_NAME = userdata.get("USER_NAME")

# !git config --global user.email {USER_EMAIL}
# !git config --global user.name {USER_NAME}
# !git remote set-url origin https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{REPO}.git

# !git add .
# !git commit -m {commit_msg}
# !git push origin master
# Out:
# Enter your commit message: 'Save evaluation results and plots'
# [master 8e1ded2] Save evaluation results and plots
#  4 files changed, 5 insertions(+)
#  create mode 100644 results/plot_consistency_rates.png
#  create mode 100644 results/plot_csqa_accuracy.png
#  create mode 100644 results/plot_gsm8k_accuracy.png
#  create mode 100644 results/summary_table.csv
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (7/7), done.
# Writing objects: 100% (7/7), 170.62 KiB | 15.51 MiB/s, done.
# Total 7 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/mohammedOwaiskh/prompt-reasoning-at-scale.git
#    ad43866..8e1ded2  master -> master
